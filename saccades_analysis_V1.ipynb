# %% [markdown]
# # Import required python packages and cleaned dataset

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from IPython.display import Image

# set pandas to show all columns in DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# set seaborn style
sns.set_style("dark")
sns.set_style("ticks")

# %%
# import dataset
saccades_an = pd.read_csv('/Users/Charlie/Desktop/saccades_charac_df.csv')

# view botoom 5 lines of imported data
saccades_an.tail()
# Out:
#        participant_num gap_overlap direction  trial timepoint Intervention  \
# 43175            37.00     overlap      left   3.00         b   Reboxetine
# 43176            37.00         gap     right   3.00         b   Reboxetine
# 43177            37.00         gap     right   3.00         b   Reboxetine
# 43178            37.00     overlap     right   3.00         b   Reboxetine
# 43179            37.00     overlap     right   3.00         b   Reboxetine
#
#       saccade_type collection_camera    status  AverageSpeed(deg/s)  \
# 43175   Prosaccade              Both  fatigued               210.08
# 43176   Prosaccade              Both  fatigued               241.95
# 43177   Prosaccade              Both  fatigued               261.22
# 43178   Prosaccade              Both  fatigued               233.59
# 43179   Prosaccade              Both  fatigued               265.54
#
#        MaxSpeed(deg/s)  Duration(ms)  Latency(ms) saccade_initiation_type Eye  \
# 43175           401.35         47.00       179.00                  normal   B
# 43176           654.05         42.00       144.00                  normal   A
# 43177           475.92         38.00       144.00                  normal   B
# 43178           604.24         43.00       139.00                  normal   A
# 43179           466.57         36.00       142.00                  normal   B
#
#        trial_presentation_number  deg_moved_in_saccade Experiment     Sex  \
# 43175                      98.00                 10.24       rave  Female
# 43176                      99.00                 10.59       rave  Female
# 43177                      99.00                 10.27       rave  Female
# 43178                     100.00                 10.08       rave  Female
# 43179                     100.00                  9.92       rave  Female
#
#        Age  Weight (kg)  Height (m)  BMI (kg/m_)  VO2max (ml/kg/min)  \
# 43175   21        64.65        1.70         22.37               49.00
# 43176   21        64.65        1.70         22.37               49.00
# 43177   21        64.65        1.70         22.37               49.00
# 43178   21        64.65        1.70         22.37               49.00
# 43179   21        64.65        1.70         22.37               49.00
#
#        60% VO2max(L/min)  Power Output 60% VO2max (W)  \
# 43175               1.88                       117.00
# 43176               1.88                       117.00
# 43177               1.88                       117.00
# 43178               1.88                       117.00
# 43179               1.88                       117.00
#
#        Target Heart Rate @ Workload (bpm)  FEV1/FVC (%)  \
# 43175                              152.00         96.30
# 43176                              152.00         96.30
# 43177                              152.00         96.30
# 43178                              152.00         96.30
# 43179                              152.00         96.30
#
#        Habitual Caffeine Use (1 = yes, 0 = no)
# 43175                                        0
# 43176                                        0
# 43177                                        0
# 43178                                        0
# 43179                                        0

# %% [markdown]
# # Purpose of analysis
# 1. To examine the similarities and differences between catecholamine treatments (DA/NA/CAF) on exercise-induced eye-movement fatigue in saccadic velocity.
#
# 2. To examine any influences of VO2max, age, and gender on oculomotor fatigue and responses to treatments intended to mitigate oculomotor fatigue.

# %% [markdown]
# ## Aim 1
# To examine the similarities and differences between catecholamine treatments on exercise-induced eye-movement fatigue (detected in saccade velocity).
#
# Step one: extract all the saccades with a normal initiation type (both pro and antisaccades)
#
# Step two: extract separate out into prosaccades and antisaccades incase we want to do further analysis on those.

# %%
# extract all saccades with a normal initiation type from the saccades_an dataset
saccades = saccades_an[saccades_an['saccade_initiation_type'] == 'normal']

# extract prosaccades with a normal initiation type from the saccades_an dataset
prosaccades = saccades_an[(saccades_an['saccade_type'] == 'Prosaccade') & 
                    (saccades_an['saccade_initiation_type'] == 'normal')]

# extract antisaccades with a normal initiation type from the saccades_an dataset
antisaccades = saccades_an[(saccades_an['saccade_type'] == 'Antisaccade') & 
                    (saccades_an['saccade_initiation_type'] == 'normal')]

# %% [markdown]
# Give count of the total number of saccades initially input into analysis:

# %%
print(len(saccades['MaxSpeed(deg/s)']))
# Out:
# 42474

# %%
saccades.groupby(['participant_num', 'saccade_type', 'Experiment', 'Intervention', 'timepoint']).describe()
# Out:
#                                                                   60% VO2max(L/min)  \
#                                                                               count
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
#                 Prosaccade   crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
# 2.00            Antisaccade  crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
#                 Prosaccade   crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
# 3.00            Antisaccade  crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
#                 Prosaccade   crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
# 4.00            Antisaccade  crave      Caffeine        a                      0.00
#                                                         b                      0.00
#                                         Placebo         a                      0.00
#                                                         b                      0.00
#                 Prosaccade   crave      Caffeine        a                      0.00
#                                                         b                      0.00
# ...                                                                             ...
# 35.00           Prosaccade   rave       Methylphenidate a                    178.00
#                                                         b                    155.00
#                                         Placebo         a                    190.00
#                                                         b                     99.00
#                                         Reboxetine      a                    157.00
#                                                         b                    121.00
# 36.00           Antisaccade  rave       Methylphenidate a                     79.00
#                                                         b                     96.00
#                                         Placebo         a                     86.00
#                                                         b                    105.00
#                                         Reboxetine      a                     66.00
#                                                         b                     60.00
#                 Prosaccade   rave       Methylphenidate a                     61.00
#                                                         b                     96.00
#                                         Placebo         a                     78.00
#                                                         b                     73.00
#                                         Reboxetine      a                     60.00
#                                                         b                     37.00
# 37.00           Antisaccade  rave       Methylphenidate a                    163.00
#                                                         b                    191.00
#                                         Placebo         a                     99.00
#                                                         b                     92.00
#                                         Reboxetine      a                    190.00
#                                                         b                    191.00
#                 Prosaccade   rave       Methylphenidate a                    178.00
#                                                         b                    197.00
#                                         Placebo         a                     99.00
#                                                         b                     98.00
#                                         Reboxetine      a                    193.00
#                                                         b                    192.00
#
#                                                                              \
#                                                                   mean  std
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 2.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 3.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 4.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
# ...                                                                ...  ...
# 35.00           Prosaccade   rave       Methylphenidate a         1.52 0.00
#                                                         b         1.52 0.00
#                                         Placebo         a         1.52 0.00
#                                                         b         1.52 0.00
#                                         Reboxetine      a         1.52 0.00
#                                                         b         1.52 0.00
# 36.00           Antisaccade  rave       Methylphenidate a         3.25 0.00
#                                                         b         3.25 0.00
#                                         Placebo         a         3.25 0.00
#                                                         b         3.25 0.00
#                                         Reboxetine      a         3.25 0.00
#                                                         b         3.25 0.00
#                 Prosaccade   rave       Methylphenidate a         3.25 0.00
#                                                         b         3.25 0.00
#                                         Placebo         a         3.25 0.00
#                                                         b         3.25 0.00
#                                         Reboxetine      a         3.25 0.00
#                                                         b         3.25 0.00
# 37.00           Antisaccade  rave       Methylphenidate a         1.88 0.00
#                                                         b         1.88 0.00
#                                         Placebo         a         1.88 0.00
#                                                         b         1.88 0.00
#                                         Reboxetine      a         1.88 0.00
#                                                         b         1.88 0.00
#                 Prosaccade   rave       Methylphenidate a         1.88 0.00
#                                                         b         1.88 0.00
#                                         Placebo         a         1.88 0.00
#                                                         b         1.88 0.00
#                                         Reboxetine      a         1.88 0.00
#                                                         b         1.88 0.00
#
#                                                                              \
#                                                                    min  25%
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 2.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 3.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 4.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
# ...                                                                ...  ...
# 35.00           Prosaccade   rave       Methylphenidate a         1.52 1.52
#                                                         b         1.52 1.52
#                                         Placebo         a         1.52 1.52
#                                                         b         1.52 1.52
#                                         Reboxetine      a         1.52 1.52
#                                                         b         1.52 1.52
# 36.00           Antisaccade  rave       Methylphenidate a         3.25 3.25
#                                                         b         3.25 3.25
#                                         Placebo         a         3.25 3.25
#                                                         b         3.25 3.25
#                                         Reboxetine      a         3.25 3.25
#                                                         b         3.25 3.25
#                 Prosaccade   rave       Methylphenidate a         3.25 3.25
#                                                         b         3.25 3.25
#                                         Placebo         a         3.25 3.25
#                                                         b         3.25 3.25
#                                         Reboxetine      a         3.25 3.25
#                                                         b         3.25 3.25
# 37.00           Antisaccade  rave       Methylphenidate a         1.88 1.88
#                                                         b         1.88 1.88
#                                         Placebo         a         1.88 1.88
#                                                         b         1.88 1.88
#                                         Reboxetine      a         1.88 1.88
#                                                         b         1.88 1.88
#                 Prosaccade   rave       Methylphenidate a         1.88 1.88
#                                                         b         1.88 1.88
#                                         Placebo         a         1.88 1.88
#                                                         b         1.88 1.88
#                                         Reboxetine      a         1.88 1.88
#                                                         b         1.88 1.88
#
#                                                                              \
#                                                                    50%  75%
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 2.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 3.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
# 4.00            Antisaccade  crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
#                                         Placebo         a          nan  nan
#                                                         b          nan  nan
#                 Prosaccade   crave      Caffeine        a          nan  nan
#                                                         b          nan  nan
# ...                                                                ...  ...
# 35.00           Prosaccade   rave       Methylphenidate a         1.52 1.52
#                                                         b         1.52 1.52
#                                         Placebo         a         1.52 1.52
#                                                         b         1.52 1.52
#                                         Reboxetine      a         1.52 1.52
#                                                         b         1.52 1.52
# 36.00           Antisaccade  rave       Methylphenidate a         3.25 3.25
#                                                         b         3.25 3.25
#                 Prosaccade   rave       Methylphenidate a         19.00
#                                                         b         19.00
#                                         Placebo         a         19.00
#                                                         b         19.00
#                                         Reboxetine      a         19.00
#                                                         b         19.00
# 37.00           Antisaccade  rave       Methylphenidate a         21.00
#                                                         b         21.00
#                                         Placebo         a         21.00
#                                                         b         21.00
#                                         Reboxetine      a         21.00
#                                                         b         21.00
#                 Prosaccade   rave       Methylphenidate a         21.00
#                                                         b         21.00
#                                         Placebo         a         21.00
#                                                         b         21.00
#                                         Reboxetine      a         21.00
#                                                         b         21.00
#
#                                                                   AverageSpeed(deg/s)  \
#                                                                                 count
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a                       97.00
#                                                         b                       98.00
#                                         Placebo         a                       99.00
#                                                         b                       94.00
#                 Prosaccade   crave      Caffeine        a                      100.00
#                                                         b                       99.00
#                                         Placebo         a                       90.00
#                                                         b                       97.00
# 2.00            Antisaccade  crave      Caffeine        a                       94.00
#                                                         b                       88.00
#                                         Placebo         a                       96.00
#                                                         b                       90.00
#                 Prosaccade   crave      Caffeine        a                       90.00
#                                                         b                       98.00
#                                         Placebo         a                       99.00
#                                                         b                      100.00
# 3.00            Antisaccade  crave      Caffeine        a                       86.00
# ...
#                                         Placebo         a         50.47 29.16
#                                                         b         50.29 27.38
#                                         Reboxetine      a         50.37 28.98
#                                                         b         51.16 28.91
#                 Prosaccade   rave       Methylphenidate a         50.34 29.22
#                                                         b         50.93 28.83
#                                         Placebo         a         50.77 29.03
#                                                         b         51.04 29.01
#                                         Reboxetine      a         51.02 28.79
#                                                         b         50.33 28.46
#
#                                                                               \
#                                                                    min   25%
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a         2.00 26.00
#                                                         b         2.00 26.50
#                                         Placebo         a         2.00 26.50
#                                                         b         1.00 24.25
#                 Prosaccade   crave      Caffeine        a         1.00 25.75
#                                                         b         1.00 25.50
#                                         Placebo         a         1.00 23.25
#                                                         b         1.00 26.00
# 2.00            Antisaccade  crave      Caffeine        a         2.00 26.25
#                                                         b         1.00 26.75
#                                         Placebo         a         1.00 26.75
#                                                         b         3.00 28.25
#                 Prosaccade   crave      Caffeine        a         1.00 29.25
#                                                         b         1.00 25.25
#                                         Placebo         a         1.00 25.50
#                                                         b         1.00 25.75
# 3.00            Antisaccade  crave      Caffeine        a         1.00 24.25
#                                                         b         1.00 25.50
#                                         Placebo         a         2.00 25.00
#                                                         b         1.00 28.00
#                 Prosaccade   crave      Caffeine        a         1.00 25.50
#                                                         b         1.00 25.75
#                                         Placebo         a         1.00 25.25
#                                                         b         2.00 26.75
# 4.00            Antisaccade  crave      Caffeine        a         1.00 25.25
#                                                         b         2.00 25.50
#                                         Placebo         a         1.00 26.25
#                                                         b         1.00 30.50
#                 Prosaccade   crave      Caffeine        a         2.00 27.00
#                                                         b         1.00 24.00
# ...                                                                ...   ...
# 35.00           Prosaccade   rave       Methylphenidate a         1.00 25.00
#                                                         b         2.00 22.50
#                                         Placebo         a         1.00 26.25
#                                                         b         1.00 26.50
#                                         Reboxetine      a         1.00 26.00
#                                                         b         1.00 19.00
# 36.00           Antisaccade  rave       Methylphenidate a         2.00 22.50
#                                                         b         1.00 25.75
#                                         Placebo         a         1.00 23.25
#                                                         b         1.00 23.00
#                                         Reboxetine      a         2.00 19.25
#                                                         b         1.00 20.75
#                 Prosaccade   rave       Methylphenidate a         1.00 22.00
#                                                         b         1.00 26.75
#                                         Placebo         a         1.00 21.25
#                                                         b         1.00 21.00
#                                         Reboxetine      a         1.00 20.25
#                                                         b         1.00 32.00
# 37.00           Antisaccade  rave       Methylphenidate a         1.00 23.50
#                                                         b         2.00 28.00
#                                         Placebo         a         1.00 25.50
#                                                         b         1.00 26.75
#                                         Reboxetine      a         1.00 25.25
#                                                         b         1.00 25.50
#                 Prosaccade   rave       Methylphenidate a         1.00 24.25
#                                                         b         1.00 26.00
#                                         Placebo         a         1.00 26.50
#                                                         b         1.00 26.25
#                                         Reboxetine      a         1.00 27.00
#                                                         b         1.00 26.75
#
#                                                                                \
#                                                                     50%   75%
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a         51.00 76.00
#                                                         b         51.50 75.75
#                                         Placebo         a         51.00 75.50
#                                                         b         47.50 70.75
#                 Prosaccade   crave      Caffeine        a         50.50 75.25
#                                                         b         50.00 74.50
#                                         Placebo         a         45.50 67.75
#                                                         b         50.00 75.00
# 2.00            Antisaccade  crave      Caffeine        a         50.50 75.75
#                                                         b         52.50 76.50
#                                         Placebo         a         52.50 76.25
#                                                         b         51.50 75.75
#                 Prosaccade   crave      Caffeine        a         53.50 76.75
#                                                         b         49.50 74.75
#                                         Placebo         a         50.00 74.50
#                                                         b         50.50 75.25
# 3.00            Antisaccade  crave      Caffeine        a         47.50 74.50
#                                                         b         51.00 75.50
#                                         Placebo         a         48.00 77.00
#                                                         b         54.00 76.00
#                 Prosaccade   crave      Caffeine        a         49.00 74.50
#                                                         b         50.50 75.25
#                                         Placebo         a         49.50 75.75
#                                                         b         50.50 75.25
# 4.00            Antisaccade  crave      Caffeine        a         48.50 73.75
#                                                         b         50.00 74.50
#                                         Placebo         a         50.50 74.75
#                                                         b         52.00 75.50
#                 Prosaccade   crave      Caffeine        a         51.00 74.00
#                                                         b         48.00 73.00
# ...                                                                 ...   ...
# 35.00           Prosaccade   rave       Methylphenidate a         53.00 76.00
#                                                         b         45.00 69.50
#                                         Placebo         a         50.50 74.00
#                                                         b         48.00 78.50
#                                         Reboxetine      a         46.00 71.00
#                                                         b         41.00 68.00
# 36.00           Antisaccade  rave       Methylphenidate a         45.00 73.00
#                                                         b         50.50 74.25
#                                         Placebo         a         46.50 73.50
#                                                         b         48.00 76.00
#                                         Reboxetine      a         40.50 66.50
#                                                         b         36.00 62.25
#                 Prosaccade   rave       Methylphenidate a         52.00 77.00
#                                                         b         51.50 76.25
#                                         Placebo         a         42.50 76.75
#                                                         b         49.00 76.00
#                                         Reboxetine      a         56.50 74.25
#                                                         b         53.00 73.00
# 37.00           Antisaccade  rave       Methylphenidate a         46.00 73.00
#                                                         b         53.00 76.50
#                                         Placebo         a         50.00 75.50
#                                                         b         50.50 73.25
#                                         Reboxetine      a         50.50 75.75
#                                                         b         52.00 75.50
#                 Prosaccade   rave       Methylphenidate a         52.00 75.75
#                                                         b         51.00 76.00
#                                         Placebo         a         51.00 75.50
#                                                         b         51.50 75.75
#                                         Reboxetine      a         51.00 76.00
#                                                         b         50.50 74.25
#
#
#                                                                      max
# participant_num saccade_type Experiment Intervention    timepoint
# 1.00            Antisaccade  crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b          95.00
#                 Prosaccade   crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a          90.00
#                                                         b         100.00
# 2.00            Antisaccade  crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                 Prosaccade   crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
# 3.00            Antisaccade  crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                 Prosaccade   crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
# 4.00            Antisaccade  crave      Caffeine        a         100.00
#                                                         b         100.00
#                                         Placebo         a          99.00
#                                                         b         100.00
#                 Prosaccade   crave      Caffeine        a         100.00
#                                                         b         100.00
# ...                                                                  ...
# 35.00           Prosaccade   rave       Methylphenidate a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                                         Reboxetine      a         100.00
#                                                         b         100.00
# 36.00           Antisaccade  rave       Methylphenidate a          99.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                                         Reboxetine      a          98.00
#                                                         b          98.00
#                 Prosaccade   rave       Methylphenidate a          98.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                                         Reboxetine      a         100.00
#                                                         b          97.00
# 37.00           Antisaccade  rave       Methylphenidate a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                                         Reboxetine      a         100.00
#                                                         b         100.00
#                 Prosaccade   rave       Methylphenidate a         100.00
#                                                         b         100.00
#                                         Placebo         a         100.00
#                                                         b         100.00
#                                         Reboxetine      a         100.00
#                                                         b         100.00
#
# [392 rows x 136 columns]

# %% [markdown]
# A total of 42474 saccades (anti and prosaccade) were compiled in this analysis.

# %% [markdown]
# ## Descriptive analysis
# The following analysis just describes means and standard deviations to look at the max speed of saccades when participants are given the intervention in an unfatigued state (either before exercise or in an experiment with no exercise) and in a fatigued state (following three hours of exercise).

# %%
# create a summary of max velocities organised into intervention and 'fatigue' status
saccades_summary = saccades.groupby(['Intervention', 'status']).agg([np.mean, np.std])
# create summary table
saccades_summary = saccades_summary['MaxSpeed(deg/s)']
# show summary for all saccades
saccades_summary
# Out:
#                              mean    std
# Intervention    status
# Bupropion       fatigued   443.53 108.13
#                 unfatigued 444.90  94.96
# Caffeine        fatigued   474.06 110.38
#                 unfatigued 452.36 103.73
# Methylphenidate fatigued   506.94 115.96
#                 unfatigued 472.97 110.64
# Placebo         fatigued   461.48 122.59
#                 unfatigued 460.78 111.29
# Reboxetine      fatigued   478.94 130.24
#                 unfatigued 487.38 111.82

# %% [markdown]
# #### Saccades summary (pro and antisaccades grouped together)
# When you look at the summary table for all of the saccades above, the story looks like it echoes what was reported in the papers when it comes to the drug interventions:
#
# Bupropion - no difference in speed between a fatigued and unfatigued state
#
# Caffeine - increases eye movement velocity when fatigue is present
#
# Methylphenidate - increases eye movement velocity in the presence of fatigue
#
# Reboxetine - decreases eye movement velocity
#
# In the case of the placebo intervention we don't see much of a difference between unfatigued and fatigued, probably because of the inclusion of the antisaccades in the dataset.

# %%
# create a summary of max velocities organised into intervention and 'fatigue' status
prosaccade_summary = prosaccades.groupby(['Intervention', 'status']).agg([np.mean, np.std])
# create summary table
prosaccade_summary = prosaccade_summary['MaxSpeed(deg/s)']
# show summary for prosaccades
prosaccade_summary
# Out:
#                              mean    std
# Intervention    status
# Bupropion       fatigued   458.70 108.44
#                 unfatigued 458.39  94.91
# Caffeine        fatigued   484.68 102.16
#                 unfatigued 464.95 100.89
# Methylphenidate fatigued   519.51 117.28
#                 unfatigued 479.33 113.58
# Placebo         fatigued   460.84 121.10
#                 unfatigued 469.89 106.42
# Reboxetine      fatigued   485.68 123.68
#                 unfatigued 507.50 111.74

# %% [markdown]
# #### Prosaccades summary
# When you look at the summary table for the prosaccades above, the results are similar to the overall summary shown above, with the addition of a reduction in eye movement velocity in the placebo intervention:
#
# Bupropion - no difference in speed between a fatigued and unfatigued state
#
# Caffeine - increases eye movement velocity when fatigue is present
#
# Methylphenidate - increases eye movement velocity in the presence of fatigue
#
# Reboxetine - slower eye movement velocity with fatigue
#
# Placebo - slower eye movement velocity with fatigue

# %%
# create a summary of max velocities organised into intervention and 'fatigue' status
antisaccade_summary = antisaccades.groupby(['Intervention', 'status']).agg([np.mean, np.std])
# create summary table
antisaccade_summary = antisaccade_summary['MaxSpeed(deg/s)']
# show summary for prosaccades
antisaccade_summary
# Out:
#                              mean    std
# Intervention    status
# Bupropion       fatigued   427.65 105.55
#                 unfatigued 430.66  92.96
# Caffeine        fatigued   463.29 117.20
#                 unfatigued 439.33 105.04
# Methylphenidate fatigued   495.96 113.68
#                 unfatigued 467.14 107.58
# Placebo         fatigued   462.06 123.98
#                 unfatigued 451.26 115.40
# Reboxetine      fatigued   472.56 135.90
#                 unfatigued 468.14 108.49

# %% [markdown]
# #### Antisaccades summary
# The summary table for the antisaccades (above) show similar results to the overall summary in response to the drug interventions. Weirdly though, there looks like there is an increase in antisaccade velocity in a fatigued state in the placebo intervention:
#
# Bupropion - no difference in speed between a fatigued and unfatigued state
#
# Caffeine - increases eye movement velocity when fatigue is present
#
# Methylphenidate - increases eye movement velocity in the presence of fatigue
#
# Reboxetine - slower eye movement velocity with fatigue
#
# Placebo - faster(?) eye movement velocity with fatigue
#
# We'll check out whether it might be because of a difference in the amplitude of the antisaccades.

# %%
# create a summary of amplitudes organised into intervention and 'fatigue' status
antisaccade_summary_amp = antisaccades.groupby(['Intervention', 'status']).agg([np.mean, np.std])
# create summary table
antisaccade_summary_amp = antisaccade_summary_amp['deg_moved_in_saccade']
# show summary for antisaccades
antisaccade_summary_amp
# Out:
#                             mean  std
# Intervention    status
# Bupropion       fatigued    8.26 2.15
#                 unfatigued  8.78 2.32
# Caffeine        fatigued    8.75 2.31
#                 unfatigued  8.81 2.28
# Methylphenidate fatigued    8.71 1.90
#                 unfatigued  8.68 2.08
# Placebo         fatigued    8.91 2.20
#                 unfatigued  8.93 2.33
# Reboxetine      fatigued    8.88 2.01
#                 unfatigued  8.99 2.10

# %% [markdown]
# #### Antisaccades amplitude
# Doesn't look like a difference in amplitude in the placebo condition between the fatigued and unfatigued conditions really played a role...I'll create visualizations for all three -> all saccades, prosaccades and antisaccades.

# %% [markdown]
# ### Create visualizations: distribution plots of max velocity across drug intervention and fatigue status

# %% [markdown]
# ## Saccade distribution plots (pro and antisaccades grouped together)

# %%
# Isolate the intervention, status and max speed data for the plots
max_velocity_all = saccades[['Intervention', 'status', 'MaxSpeed(deg/s)']]
max_velocity_pro = prosaccades[['Intervention', 'status', 'MaxSpeed(deg/s)']]
max_velocity_anti = antisaccades[['Intervention', 'status', 'MaxSpeed(deg/s)']]

# %% [markdown]
# ### Create violin plots

# %%
ax = sns.violinplot(x='Intervention', y='MaxSpeed(deg/s)', data=max_velocity_all, hue='status', 
                    split=True, order=['Placebo', 'Caffeine', 'Bupropion', 'Methylphenidate', 
                                       'Reboxetine'], scale='count', inner='quartile')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('All saccades: max speed by Intervention')
plt.show()

# %% [markdown]
# #### Saccades violin plot: max speed by intervention
# The violin plots are scaled based on the number of observations and have the quartiles of each distribution displayed within the violin splits as 'sticks' or dashed lines.
#
# The number of observations in the 'unfatigued' placebo and caffeine are twice as large as the 'fatigued' side of the violin because of the crave study. Like the summary tables showed, when both types of eye movement are included in the data set, there is little difference in the max velocity between unfatigued and fatigued states with the placebo, aside from a wider interquartile range when fatigued with placebo.
#
# Bupropion looks similar between fatigued and unfatigued.
#
# Reboxetine has a greater number of observations at the lower end of the distribution in the presence of fatigue, which has pulled down the median relative to the unfatigued condition
#
# Having Methylphenidate and Caffeine when fatigue looks like it results in a shift up of the distribution, resulting in faster eye movements.

# %%
ax = sns.violinplot(x='Intervention', y='MaxSpeed(deg/s)', data=max_velocity_pro, hue='status', 
                    split=True, order=['Placebo', 'Caffeine', 'Bupropion', 'Methylphenidate', 
                                       'Reboxetine'], scale='count', inner='quartile')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Prosaccades: max speed by Intervention')
plt.show()

# %% [markdown]
# #### Prosaccades violin plot: max speed by intervention
#
# Unlike when both saccade types are included in the dataset, when it is just the prosaccades you can see a lower max velocity in the fatigued compared to the unfatigued state with the placebo.
#
# The effects of the other interventions on max speed in the prosaccades is the same as described for the dataset with both saccade types included.

# %%
ax = sns.violinplot(x='Intervention', y='MaxSpeed(deg/s)', data=max_velocity_anti, hue='status', 
                    split=True, order=['Placebo', 'Caffeine', 'Bupropion', 'Methylphenidate', 
                                       'Reboxetine'], scale='count', inner='quartile')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Antisaccades: max speed by Intervention')
plt.show()

# %% [markdown]
# #### Antisaccades violin plot: max speed by intervention
#
# When it is just antisaccades in the dataset there is little difference in the distribution of max velocity (aside from the number of observations) in the fatigued compared to the unfatigued state with the placebo.
#
# The effects of the other interventions on max speed in the prosaccades is the similar to the effects described for the dataset with both saccade types included.

# %% [markdown]
# ## Aim 2
# To examine any influences of VO2max, age, and gender on oculomotor fatigue and responses to drug interventions on saccadic eye movement speed in the presence and absence of exercise fatigue.

# %% [markdown]
# ### Add eye movement fatigue classifier
# I want to add a classifier that says whether or not the participant exhibited faster, slower or no difference in eye movement speed after the exercise and/or drug intervention.
#
# First step is to group the saccade dataset by participant, intervention and timepoint. Next means need to be calculated, followed by the generation of a bootstrap 90% CI. Once this has been down for each participant at each timepoint, I can then use the bounds of the CI to decide if the participant displayed a significant difference in eye movement speed pre to post intervention and/or exercise.

# %%
# group the dataset by participant, intervention and timepoint
prosaccade_bs = prosaccades.groupby(['participant_num', 'Intervention'])
antisaccade_bs = antisaccades.groupby(['participant_num', 'Intervention'])

# define functions for bootstrapping methods

def bootstrap_replicate_1d(data, func):
    return func(np.random.choice(data, size=len(data)))


def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""

    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)

    return bs_replicates

def diff_of_means(data_1, data_2):
    """Difference in means of two arrays."""

    # The difference of means of data_1, data_2: diff
    diff = np.mean(data_1) - np.mean(data_2)

    return diff

# create participant summary based on groups
def percentile(n):
    """percentile function to use in pandas.agg to add percentiles to grouped columns"""
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

# %% [markdown]
# # Bootstrap method to find confidence intervals for each participant at each timepoint.
# Using these confidence intervals, I can classify whether pre to post the participants EM's
# slowed down at the 'post' timepoint by comparing the the upper and lower bounds of the CI for the mean speed post relative to the CI for the mean speed pre. There is a third possibility too - that the eye movement increased in speed, but to begin with I am just going to do a logistic regression with a binary classifier, i.e. did eye movements slow down pre to post: 1 = yes, 0 = no.

# %%
def saccade_bs(grouped_data, saccade_type='saccade'):
    
    bs_results = pd.DataFrame(columns=['participant_num', 'intervention', 'saccade_type',
                                   'EM_change'])
    for name, group in grouped_data:
        # isolate timepoints within the group
        pre = group[group['timepoint'] == 'a']
        post = group[group['timepoint'] == 'b']
        
        # isolate pre and post data within groups
        pre_variable = pre['MaxSpeed(deg/s)']
        post_variable = post['MaxSpeed(deg/s)']
        
        # Compute 10,000 bootstrap replicates from pre and post data
        bs_replicates_pre = draw_bs_reps(pre_variable, np.mean, size=10000)
        bs_replicates_post = draw_bs_reps(post_variable, np.mean, size=10000)
        
        # Compute  90% CI of the mean for pre and post
        pre_lower_bound, pre_upper_bound = np.percentile(bs_replicates_pre,[5, 95])
        post_lower_bound, post_upper_bound = np.percentile(bs_replicates_post,[5, 95])
        
        # did eye movements slow, get faster or not change pre to post?
        # boolean argument for slower EMs post
        if post_upper_bound <= pre_lower_bound:
            bs_results.loc[str(name[0]) + '_' + str(name[1]) + 
                           '_' + saccade_type] = [name[0], name[1], saccade_type, 1]
            # no change in EMs
        else:
            bs_results.loc[str(name[0]) + '_' + str(name[1]) + 
                           '_'+ saccade_type] = [name[0], name[1], saccade_type, 0]
    return bs_results

# %%
# create bootstraps for prosaccade data
bs_prosaccades = saccade_bs(prosaccade_bs, saccade_type='Prosaccade')

# %%
bs_prosaccades.describe()
# Out:
#        participant_num
# count            98.00
# mean             20.59
# std              10.33
# min               1.00
# 25%              13.00
# 50%              21.00
# 75%              29.00
# max              37.00

# %%
# create bootstraps for antisaccade data
bs_antisaccades = saccade_bs(antisaccade_bs, saccade_type='Antisaccade')

# %%
bs_antisaccades.describe()
# Out:
#        participant_num
# count            98.00
# mean             20.59
# std              10.33
# min               1.00
# 25%              13.00
# 50%              21.00
# 75%              29.00
# max              37.00

# %%
bs_saccades = pd.concat([bs_antisaccades, bs_prosaccades])
bs_saccades
# Out:
#                                  participant_num     intervention  \
# 1.0_Caffeine_Antisaccade                    1.00         Caffeine
# 1.0_Placebo_Antisaccade                     1.00          Placebo
# 2.0_Caffeine_Antisaccade                    2.00         Caffeine
# 2.0_Placebo_Antisaccade                     2.00          Placebo
# 3.0_Caffeine_Antisaccade                    3.00         Caffeine
# 3.0_Placebo_Antisaccade                     3.00          Placebo
# 4.0_Caffeine_Antisaccade                    4.00         Caffeine
# 4.0_Placebo_Antisaccade                     4.00          Placebo
# 5.0_Caffeine_Antisaccade                    5.00         Caffeine
# 5.0_Placebo_Antisaccade                     5.00          Placebo
# 6.0_Caffeine_Antisaccade                    6.00         Caffeine
# 6.0_Placebo_Antisaccade                     6.00          Placebo
# 7.0_Caffeine_Antisaccade                    7.00         Caffeine
# 7.0_Placebo_Antisaccade                     7.00          Placebo
# 8.0_Caffeine_Antisaccade                    8.00         Caffeine
# 8.0_Placebo_Antisaccade                     8.00          Placebo
# 9.0_Caffeine_Antisaccade                    9.00         Caffeine
# 9.0_Placebo_Antisaccade                     9.00          Placebo
# 10.0_Caffeine_Antisaccade                  10.00         Caffeine
# 10.0_Placebo_Antisaccade                   10.00          Placebo
# 11.0_Caffeine_Antisaccade                  11.00         Caffeine
# 11.0_Placebo_Antisaccade                   11.00          Placebo
# 12.0_Caffeine_Antisaccade                  12.00         Caffeine
# 12.0_Placebo_Antisaccade                   12.00          Placebo
# 13.0_Caffeine_Antisaccade                  13.00         Caffeine
# 13.0_Placebo_Antisaccade                   13.00          Placebo
# 14.0_Bupropion_Antisaccade                 14.00        Bupropion
# 14.0_Caffeine_Antisaccade                  14.00         Caffeine
# 14.0_Placebo_Antisaccade                   14.00          Placebo
# 15.0_Bupropion_Antisaccade                 15.00        Bupropion
# ...                                          ...              ...
# 28.0_Methylphenidate_Prosaccade            28.00  Methylphenidate
# 28.0_Placebo_Prosaccade                    28.00          Placebo
# 28.0_Reboxetine_Prosaccade                 28.00       Reboxetine
# 29.0_Methylphenidate_Prosaccade            29.00  Methylphenidate
# 29.0_Placebo_Prosaccade                    29.00          Placebo
# 29.0_Reboxetine_Prosaccade                 29.00       Reboxetine
# 30.0_Methylphenidate_Prosaccade            30.00  Methylphenidate
# 30.0_Placebo_Prosaccade                    30.00          Placebo
# 30.0_Reboxetine_Prosaccade                 30.00       Reboxetine
# 31.0_Methylphenidate_Prosaccade            31.00  Methylphenidate
# 31.0_Placebo_Prosaccade                    31.00          Placebo
# 31.0_Reboxetine_Prosaccade                 31.00       Reboxetine
# 32.0_Methylphenidate_Prosaccade            32.00  Methylphenidate
# 32.0_Placebo_Prosaccade                    32.00          Placebo
# 32.0_Reboxetine_Prosaccade                 32.00       Reboxetine
# 33.0_Methylphenidate_Prosaccade            33.00  Methylphenidate
# 33.0_Placebo_Prosaccade                    33.00          Placebo
# 33.0_Reboxetine_Prosaccade                 33.00       Reboxetine
# 34.0_Methylphenidate_Prosaccade            34.00  Methylphenidate
# 34.0_Placebo_Prosaccade                    34.00          Placebo
# 34.0_Reboxetine_Prosaccade                 34.00       Reboxetine
# 35.0_Methylphenidate_Prosaccade            35.00  Methylphenidate
# 35.0_Placebo_Prosaccade                    35.00          Placebo
# 35.0_Reboxetine_Prosaccade                 35.00       Reboxetine
# 36.0_Methylphenidate_Prosaccade            36.00  Methylphenidate
# 36.0_Placebo_Prosaccade                    36.00          Placebo
# 36.0_Reboxetine_Prosaccade                 36.00       Reboxetine
# 37.0_Methylphenidate_Prosaccade            37.00  Methylphenidate
# 37.0_Placebo_Prosaccade                    37.00          Placebo
# 37.0_Reboxetine_Prosaccade                 37.00       Reboxetine
#
#                                 saccade_type EM_change
# 1.0_Caffeine_Antisaccade         Antisaccade         1
# 1.0_Placebo_Antisaccade          Antisaccade         0
# 2.0_Caffeine_Antisaccade         Antisaccade         1
# 2.0_Placebo_Antisaccade          Antisaccade         0
# 3.0_Caffeine_Antisaccade         Antisaccade         0
# 3.0_Placebo_Antisaccade          Antisaccade         1
# 4.0_Caffeine_Antisaccade         Antisaccade         0
# 4.0_Placebo_Antisaccade          Antisaccade         0
# 5.0_Caffeine_Antisaccade         Antisaccade         0
# 5.0_Placebo_Antisaccade          Antisaccade         0
# 6.0_Caffeine_Antisaccade         Antisaccade         1
# 6.0_Placebo_Antisaccade          Antisaccade         0
# 7.0_Caffeine_Antisaccade         Antisaccade         0
# 7.0_Placebo_Antisaccade          Antisaccade         0
# 8.0_Caffeine_Antisaccade         Antisaccade         0
# 8.0_Placebo_Antisaccade          Antisaccade         0
# 9.0_Caffeine_Antisaccade         Antisaccade         1
# 9.0_Placebo_Antisaccade          Antisaccade         1
# 10.0_Caffeine_Antisaccade        Antisaccade         0
# 10.0_Placebo_Antisaccade         Antisaccade         1
# 11.0_Caffeine_Antisaccade        Antisaccade         0
# 11.0_Placebo_Antisaccade         Antisaccade         0
# 12.0_Caffeine_Antisaccade        Antisaccade         0
# 12.0_Placebo_Antisaccade         Antisaccade         0
# 13.0_Caffeine_Antisaccade        Antisaccade         0
# 13.0_Placebo_Antisaccade         Antisaccade         0
# 14.0_Bupropion_Antisaccade       Antisaccade         0
# 14.0_Caffeine_Antisaccade        Antisaccade         1
# 14.0_Placebo_Antisaccade         Antisaccade         0
# 15.0_Bupropion_Antisaccade       Antisaccade         0
# ...                                      ...       ...
# 28.0_Methylphenidate_Prosaccade   Prosaccade         0
# 28.0_Placebo_Prosaccade           Prosaccade         0
# 28.0_Reboxetine_Prosaccade        Prosaccade         1
# 29.0_Methylphenidate_Prosaccade   Prosaccade         0
# 29.0_Placebo_Prosaccade           Prosaccade         1
# 29.0_Reboxetine_Prosaccade        Prosaccade         0
# 30.0_Methylphenidate_Prosaccade   Prosaccade         0
# 30.0_Placebo_Prosaccade           Prosaccade         1
# 30.0_Reboxetine_Prosaccade        Prosaccade         0
# 31.0_Methylphenidate_Prosaccade   Prosaccade         0
# 31.0_Placebo_Prosaccade           Prosaccade         0
# 31.0_Reboxetine_Prosaccade        Prosaccade         0
# 32.0_Methylphenidate_Prosaccade   Prosaccade         0
# 32.0_Placebo_Prosaccade           Prosaccade         1
# 32.0_Reboxetine_Prosaccade        Prosaccade         1
# 33.0_Methylphenidate_Prosaccade   Prosaccade         0
# 33.0_Placebo_Prosaccade           Prosaccade         0
# 33.0_Reboxetine_Prosaccade        Prosaccade         1
# 34.0_Methylphenidate_Prosaccade   Prosaccade         0
# 34.0_Placebo_Prosaccade           Prosaccade         0
# 34.0_Reboxetine_Prosaccade        Prosaccade         0
# 35.0_Methylphenidate_Prosaccade   Prosaccade         1
# 35.0_Placebo_Prosaccade           Prosaccade         0
# 35.0_Reboxetine_Prosaccade        Prosaccade         1
# 36.0_Methylphenidate_Prosaccade   Prosaccade         0
# 36.0_Placebo_Prosaccade           Prosaccade         1
# 36.0_Reboxetine_Prosaccade        Prosaccade         0
# 37.0_Methylphenidate_Prosaccade   Prosaccade         0
# 37.0_Placebo_Prosaccade           Prosaccade         1
# 37.0_Reboxetine_Prosaccade        Prosaccade         0
#
# [196 rows x 4 columns]

# %% [markdown]
# Now we have a table that holds a binary classifier that signifying whether the participants eye movement velocity (for saccades of a particular intervention and type (anti or pro) displayed a reduction in velocity post experiment. What we need to do now is merge that table with the saccades table that contains all the rest of the participant information. In addition, categorical variables need to be altered to have numbers signifying the categories as opposed to strings.

# %%
# merge the prosaccades data and the classifier data to create a new dataframe that includes the 
# classifier
saccades_classifier = pd.merge(saccades, bs_saccades,  how='left', 
                                  left_on=['participant_num','Intervention', 'saccade_type'], 
                                  right_on = ['participant_num','intervention', 'saccade_type'])
del saccades_classifier['intervention']
sex = {'Male': 0, 'Female': 1}
saccades_classifier['sex'] = saccades_classifier['Sex'].map(sex)
del saccades_classifier['Sex']
saccades_classifier.set_index('participant_num')
saccades_classifier.head()
# Out:
#    participant_num gap_overlap direction  trial timepoint Intervention  \
# 0             1.00         gap      left   1.00         a     Caffeine
# 1             1.00         gap      left   1.00         a     Caffeine
# 2             1.00         gap     right   1.00         a     Caffeine
# 3             1.00         gap      left   1.00         a     Caffeine
# 4             1.00     overlap      left   1.00         a     Caffeine
#
#   saccade_type collection_camera      status  AverageSpeed(deg/s)  \
# 0  Antisaccade                 A  unfatigued               208.70
# 1  Antisaccade                 A  unfatigued               198.92
# 2  Antisaccade                 A  unfatigued               224.68
# 3  Antisaccade                 A  unfatigued               222.08
# 4  Antisaccade                 A  unfatigued               180.76
#
#    MaxSpeed(deg/s)  Duration(ms)  Latency(ms) saccade_initiation_type Eye  \
# 0           537.84         44.00       273.00                  normal   A
# 1           414.95         40.00       286.00                  normal   A
# 2           548.49         42.00       272.00                  normal   A
# 3           418.14         34.00       190.00                  normal   A
# 4           601.81         52.00       351.00                  normal   A
#
#    trial_presentation_number  deg_moved_in_saccade Experiment  Age  \
# 0                       2.00                  9.03      crave   25
# 1                       3.00                  8.16      crave   25
# 2                       4.00                  8.92      crave   25
# 3                       5.00                  7.57      crave   25
# 4                       6.00                  9.38      crave   25
#
#    Weight (kg)  Height (m)  BMI (kg/m_)  VO2max (ml/kg/min)  \
# 0        59.40        1.68         20.97               42.00
# 1        59.40        1.68         20.97               42.00
# 2        59.40        1.68         20.97               42.00
# 3        59.40        1.68         20.97               42.00
# 4        59.40        1.68         20.97               42.00
#
#    60% VO2max(L/min)  Power Output 60% VO2max (W)  \
# 0                nan                          nan
# 1                nan                          nan
# 2                nan                          nan
# 3                nan                          nan
# 4                nan                          nan
#
#    Target Heart Rate @ Workload (bpm)  FEV1/FVC (%)  \
# 0                                 nan         95.80
# 1                                 nan         95.80
# 2                                 nan         95.80
# 3                                 nan         95.80
# 4                                 nan         95.80
#
#    Habitual Caffeine Use (1 = yes, 0 = no) EM_change  sex
# 0                                        1         1    1
# 1                                        1         1    1
# 2                                        1         1    1
# 3                                        1         1    1
# 4                                        1         1    1

# %%
saccades_regression = saccades_classifier.groupby(['participant_num', 'Experiment', 'Intervention', 
                                                 'EM_change', 'saccade_type']).agg([np.mean])
saccades_regression = saccades_regression.reset_index()
saccades_regression.columns = saccades_regression.columns.droplevel(1)
saccades_regression.columns
# Out:
# Index(['participant_num', 'Experiment', 'Intervention', 'EM_change',
#        'saccade_type', 'trial', 'AverageSpeed(deg/s)', 'MaxSpeed(deg/s)',
#        'Duration(ms)', 'Latency(ms)', 'trial_presentation_number',
#        'deg_moved_in_saccade', 'Age', 'Weight (kg)', 'Height (m)',
#        'BMI (kg/m_)', 'VO2max (ml/kg/min)', '60% VO2max(L/min)',
#        'Power Output 60% VO2max (W)', 'Target Heart Rate @ Workload (bpm)',
#        'FEV1/FVC (%)', 'Habitual Caffeine Use (1 = yes, 0 = no)', 'sex'],
#       dtype='object')

# %%
# prepare the dataset for input into the conditional logistic regresion

saccades_regression = saccades_regression.groupby(['participant_num', 'Experiment', 'Intervention', 
                                                 'EM_change', 'saccade_type']).agg([np.mean])
saccades_regression = saccades_regression.reset_index()
saccades_regression.columns = saccades_regression.columns.droplevel(1)
saccades_regression = saccades_regression[['participant_num', 'Age', 'Weight (kg)', 'Height (m)', 'BMI (kg/m_)',
                                      'VO2max (ml/kg/min)', 'Habitual Caffeine Use (1 = yes, 0 = no)', 
                                       'sex', 'Experiment', 'Intervention', 'saccade_type', 'EM_change']]

# change the column names
saccades_regression = saccades_regression.rename(index=str, columns={'BMI (kg/m_)': 'BMI', 
                                                                 'VO2max (ml/kg/min)': 'VO2max', 
                                                                 'Weight (kg)': 'Weight',
                                                                 'Habitual Caffeine Use (1 = yes, 0 = no)': 'Caffeine_use', 
                                                                 'Height (m)': 'Height'})

# inspect the dataset for missing values
saccades_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196 entries, 0 to 195
# Data columns (total 12 columns):
# participant_num    196 non-null float64
# Age                196 non-null int64
# Weight             196 non-null float64
# Height             196 non-null float64
# BMI                196 non-null float64
# VO2max             192 non-null float64
# Caffeine_use       196 non-null int64
# sex                196 non-null int64
# Experiment         196 non-null object
# Intervention       196 non-null object
# saccade_type       196 non-null object
# EM_change          196 non-null int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 19.9+ KB

# %% [markdown]
# The only column with null values is VO2max. This will be due to the one participant in the crave study that we couldn't do a max test for. There are four null entries for this person because their eye movements were measured at four timepoints - pre and post placebo, and pre and post caffeine. We can either:
# 1. drop the rows with the missing values
# 2. fill the missing values with an estimate of this participants VO2max
#
# Lets look at the characteristics of this participant:

# %%
saccades_regression[saccades_regression.isnull().any(axis=1)]
# Out:
#     participant_num  Age  Weight  Height   BMI  VO2max  Caffeine_use  sex  \
# 16             5.00   24   81.75    1.84 24.17     nan             1    0
# 17             5.00   24   81.75    1.84 24.17     nan             1    0
# 18             5.00   24   81.75    1.84 24.17     nan             1    0
# 19             5.00   24   81.75    1.84 24.17     nan             1    0
#
#    Experiment Intervention saccade_type  EM_change
# 16      crave     Caffeine  Antisaccade          0
# 17      crave     Caffeine   Prosaccade          0
# 18      crave      Placebo  Antisaccade          0
# 19      crave      Placebo   Prosaccade          0

# %% [markdown]
# The participant that we don't have the aerobic capacity for is male, age 24, 81.75 kg and 1.84 m. We will fill this value with the mean aerobic capacity of males in the dataset.

# %%
male_vo2 = saccades_regression[saccades_regression.notnull().any(axis=1) & 
                               saccades_regression['sex']==0]
male_vo2 = male_vo2['VO2max'].mean()
saccades_regression_fill = saccades_regression.fillna(male_vo2)
saccades_regression_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196 entries, 0 to 195
# Data columns (total 12 columns):
# participant_num    196 non-null float64
# Age                196 non-null int64
# Weight             196 non-null float64
# Height             196 non-null float64
# BMI                196 non-null float64
# VO2max             196 non-null float64
# Caffeine_use       196 non-null int64
# sex                196 non-null int64
# Experiment         196 non-null object
# Intervention       196 non-null object
# saccade_type       196 non-null object
# EM_change          196 non-null int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 24.9+ KB

# %% [markdown]
# Get a count of the number of participants that were input into analysis:

# %%
print(len(saccades_regression_fill.groupby('participant_num')))
# Out:
# 37

# %% [markdown]
# ### Save .csv versions of the dataset with and without the null values

# %%
saccades_regression.to_csv('/Users/Charlie/Desktop/saccades_analysis_null.csv')
saccades_regression_fill.to_csv('/Users/Charlie/Desktop/saccades_analysis_nonull.csv')

# %% [markdown]
# ### Import the dataset

# %%
data_saccades = pd.read_csv('/Users/Charlie/Desktop/saccades_analysis_nonull.csv')
del data_saccades['Unnamed: 0']
data_saccades.head()
# Out:
#    participant_num  Age  Weight  Height   BMI  VO2max  Caffeine_use  sex  \
# 0             1.00   25   59.40    1.68 20.97   42.00             1    1
# 1             1.00   25   59.40    1.68 20.97   42.00             1    1
# 2             1.00   25   59.40    1.68 20.97   42.00             1    1
# 3             1.00   25   59.40    1.68 20.97   42.00             1    1
# 4             2.00   24   64.65    1.69 22.74   56.00             1    1
#
#   Experiment Intervention saccade_type  EM_change
# 0      crave     Caffeine  Antisaccade          1
# 1      crave     Caffeine   Prosaccade          1
# 2      crave      Placebo  Antisaccade          0
# 3      crave      Placebo   Prosaccade          0
# 4      crave     Caffeine   Prosaccade          0

# %% [markdown]
# We need to create a classifier for whether the participant had performed fatiguing exercise prior to eye movement measurement:

# %%
exercise = {'crave': 'no', 'feeble': 'yes', 'rave': 'yes'}
data_saccades['exercise_intervention'] = data_saccades['Experiment'].map(exercise)

# %% [markdown]
# ## Data Exploration

# %%
# data summary
print ('Number of observations :: ', len(data_saccades.index))
print ('Number of columns :: ', len(data_saccades.columns))
print ('Headers :: ', data_saccades.columns.values)
# Out:
# Number of observations ::  196
# Number of columns ::  12
# Headers ::  ['participant_num' 'Age' 'Weight' 'Height' 'BMI' 'VO2max' 'Caffeine_use'
#  'sex' 'Experiment' 'Intervention' 'saccade_type' 'EM_change']

# %%
data_saccades['EM_change'].value_counts()
# Out:
# 0    143
# 1     53
# Name: EM_change, dtype: int64

# %%
sns.countplot(x='EM_change', data=data_saccades)
plt.show()

# %% [markdown]
# The graph above shows that there were 53 instances where participants exhibited slower eye movements at the 'post' measurement timepoint.

# %%
data_saccades.groupby('EM_change').mean()
# Out:
#            participant_num   Age  Weight  Height   BMI  VO2max  Caffeine_use  \
# EM_change
# 0                    20.32 24.01   73.25    1.76 23.56   57.17          0.59
# 1                    21.32 25.58   68.00    1.70 23.48   53.13          0.70
#
#            sex
# EM_change
# 0         0.50
# 1         0.75

# %% [markdown]
# The table above gives a sense of the numbers across the two classes.
#
# ### General observations:
# - The average age of those who didn't exhibit fatigue was less than those who did
# - VO2max was higher in those who didn't exhibit slower eye movements
#
# Calculating categorical means for the variables sex, exercise intervention, drug, saccade and caffeine use will give a more detailed sense of the data (NOTE: look at the features list if you want to know the categories that each of the numbers signify):

# %%
data_saccades.groupby('Caffeine_use').mean()
# Out:
#               participant_num   Age  Weight  Height   BMI  VO2max  sex  \
# Caffeine_use
# 0                       22.46 21.08   75.69    1.76 24.14   54.01 0.43
# 1                       19.46 26.48   69.49    1.73 23.18   57.34 0.66
#
#               EM_change
# Caffeine_use
# 0                  0.22
# 1                  0.30

# %%
data_saccades.groupby('sex').mean()
# Out:
#      participant_num   Age  Weight  Height   BMI  VO2max  Caffeine_use  \
# sex
# 0              19.86 22.83   83.58    1.83 24.85   58.89          0.50
# 1              21.14 25.64   63.02    1.67 22.55   53.97          0.71
#
#      EM_change
# sex
# 0         0.15
# 1         0.36

# %% [markdown]
# # Visualizations

# %%
# %matplotlib inline
pd.crosstab(data_saccades.Age, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Keep in mind that the sample we have over represents people in their twenties.

# %%
pd.crosstab(data_saccades.exercise_intervention, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by exercise intervention')
plt.xlabel('Exercise intervention (0 = no; 1= yes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# As you would expect, there are more participants exhibiting a change in eye movement speed if they have performed exercise as a part of the experimental trial.

# %%
table=pd.crosstab(data_saccades.Intervention, data_saccades.EM_change)
table.div(table.sum(1). astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked bar chart of Drug versus EM_change')
plt.xlabel('Drug')
plt.ylabel('Proportion of participants')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
data_saccades.VO2max = data_saccades.VO2max.round()
pd.crosstab(data_saccades.VO2max, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by aerobic capacity')
plt.xlabel('Aerobic capacity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# It looks as though people with a lower aerobic capacity may be more susceptible to a reduction in their eye movement velocity at the post timepoint compared to those with a higher aerobic fitness

# %%
table=pd.crosstab(data_saccades.sex, data_saccades.EM_change)
table.div(table.sum(1). astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked bar chart of Sex versus EM_change')
plt.xlabel('Sex')
plt.ylabel('Proportion of participants')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# A higher proportion of females exhibited slower eye movements compared to males, although there were more females in the sample than males.

# %%
table=pd.crosstab(data_saccades.Caffeine_use, data_saccades.EM_change)
table.div(table.sum(1). astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked bar chart of caffeine use versus EM_change')
plt.xlabel('Caffeine use')
plt.ylabel('Proportion of participants')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Whether a person drinks caffeine habitually or not doesn't appear to be a strong indicator of whether participants exhibited slower eye movements at the 'post' timepoint

# %%
table=pd.crosstab(data_saccades.saccade_type, data_saccades.EM_change)
table.div(table.sum(1). astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked bar chart of saccade type versus EM_change')
plt.xlabel('Saccade type')
plt.ylabel('Proportion of participants')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
table
# Out:
# EM_change      0   1
# saccade_type
# Antisaccade   71  27
# Prosaccade    72  26

# %% [markdown]
# Strangely, it doesn't look like saccade type is a great predictor of whether a persons eye movements slow or not.

# %%
data_saccades.BMI = data_saccades.BMI.round()
pd.crosstab(data_saccades.BMI, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
data_saccades.Weight = data_saccades.Weight.round()
pd.crosstab(data_saccades.Weight, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by Weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()

# %%
data_saccades.Height = data_saccades.Height.round(1)
pd.crosstab(data_saccades.Height, data_saccades.EM_change).plot(kind='bar')
plt.title('EM_change frequency by Height')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Create dummy data

# %%
data_saccades_dummies = pd.get_dummies(data_saccades, drop_first=True)
data_saccades_dummies.head()
# Out:
#    participant_num  Age  Weight  Height   BMI  VO2max  Caffeine_use  sex  \
# 0             1.00   25   59.00    1.70 21.00   42.00             1    1
# 1             1.00   25   59.00    1.70 21.00   42.00             1    1
# 2             1.00   25   59.00    1.70 21.00   42.00             1    1
# 3             1.00   25   59.00    1.70 21.00   42.00             1    1
# 4             2.00   24   65.00    1.70 23.00   56.00             1    1
#
#    EM_change  Experiment_feeble  Experiment_rave  Intervention_Caffeine  \
# 0          1                  0                0                      1
# 1          1                  0                0                      1
# 2          0                  0                0                      0
# 3          0                  0                0                      0
# 4          0                  0                0                      1
#
#    Intervention_Methylphenidate  Intervention_Placebo  \
# 0                             0                     0
# 1                             0                     0
# 2                             0                     1
# 3                             0                     1
# 4                             0                     0
#
#    Intervention_Reboxetine  saccade_type_Prosaccade  exercise_intervention_yes
# 0                        0                        0                          0
# 1                        0                        1                          0
# 2                        0                        0                          0
# 3                        0                        1                          0
# 4                        0                        1                          0

# %% [markdown]
# ### ... to be continued

# %% [markdown]
# # Exploring the influence of sex and aerobic capacity on eye movement speed
#
# The code below groups the data into pro and antisaccades, calculating the mean change in eye movement speed pre to post for each participant/intervention. Then recombining this into the dataset where the participant characteristics are.

# %%
def saccade_speed_diff(grouped_data, saccade_type='saccade'):
    
    sacccade_speed_results = pd.DataFrame(columns=['participant_num', 'intervention', 
                                                   'saccade_type', 'EM_change'])
    for name, group in grouped_data:
        # isolate timepoints within the group
        pre = group[group['timepoint'] == 'a']
        post = group[group['timepoint'] == 'b']
        
        # isolate pre and post data within groups
        pre_variable = pre['MaxSpeed(deg/s)']
        post_variable = post['MaxSpeed(deg/s)']
        
        # compute mean difference between pre and post
        speed_diff = np.mean(post_variable) - np.mean(pre_variable)
        
        # add speed differential to saccade_speed_results
        sacccade_speed_results.loc[str(name[0]) + '_' + str(name[1]) + '_' 
                                   + saccade_type] = [name[0], name[1], saccade_type, speed_diff]

    return sacccade_speed_results

# %%
# group the dataset by participant, intervention and timepoint
prosaccade_diff = prosaccades.groupby(['participant_num', 'Intervention'])
antisaccade_diff = antisaccades.groupby(['participant_num', 'Intervention'])

# find speed differences for prosaccade and antisaccade data
speed_diff_prosaccades = saccade_speed_diff(prosaccade_diff, saccade_type='Prosaccade')
speed_diff_antisaccades = saccade_speed_diff(antisaccade_diff, saccade_type='Antisaccade')

# concatenate prosaccades and antisaccades
speed_diff_saccades = pd.concat([speed_diff_prosaccades, speed_diff_antisaccades])

# merge the prosaccades data and the classifier data to create a new dataframe that includes the 
# classifier
saccades_diff = pd.merge(saccades, speed_diff_saccades,  how='left', 
                                  left_on=['participant_num','Intervention', 'saccade_type'], 
                                  right_on = ['participant_num','intervention', 'saccade_type'])
saccades_diff.set_index('participant_num')
# Out:
#                 gap_overlap direction  trial timepoint Intervention  \
# participant_num
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                overlap     right   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap      left   1.00         a     Caffeine
# 1.00                    gap     right   1.00         a     Caffeine
# 1.00                overlap      left   1.00         a     Caffeine
# ...                     ...       ...    ...       ...          ...
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap      left   3.00         b   Reboxetine
# 37.00                   gap      left   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap      left   3.00         b   Reboxetine
# 37.00                   gap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00               overlap      left   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00                   gap     right   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
# 37.00               overlap     right   3.00         b   Reboxetine
#
#                 saccade_type collection_camera      status  \
# participant_num
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# 1.00             Antisaccade                 A  unfatigued
# ...                      ...               ...         ...
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
# 37.00             Prosaccade              Both    fatigued
#
#                  AverageSpeed(deg/s)  MaxSpeed(deg/s)  Duration(ms)  \
# participant_num
# 1.00                          208.70           537.84         44.00
# 1.00                          198.92           414.95         40.00
# 1.00                          224.68           548.49         42.00
# 1.00                          222.08           418.14         34.00
# 1.00                          180.76           601.81         52.00
# 1.00                          215.43           472.97         42.00
# 1.00                          199.30           788.86         47.00
# 1.00                          250.30           427.92         35.00
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# 1.00                                                   1     Caffeine
# ...                                                  ...          ...
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
# 37.00                                                  0   Reboxetine
#
#                  EM_change
# participant_num
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# 1.00                -52.25
# ...                    ...
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
# 37.00                -7.44
#
# [42474 rows x 30 columns]

# %%
sex = {'Male': 0, 'Female': 1}
saccades_diff['sex'] = saccades_diff['Sex'].map(sex)
del saccades_diff['Sex']
exercise = {'crave': 0, 'feeble': 1, 'rave': 1}
saccades_diff['exercise_intervention'] = saccades_diff['Experiment'].map(exercise)
saccades_diff = saccades_diff.groupby(['participant_num', 'Experiment', 'Intervention', 
                                       'EM_change', 'saccade_type']).agg([np.mean])
saccades_diff = saccades_diff.reset_index()
saccades_diff.columns = saccades_diff.columns.droplevel(1)

# retain only useful columns
saccades_diff = saccades_diff[['VO2max (ml/kg/min)', 'sex', 'Experiment', 'Intervention', 
                               'saccade_type', 'EM_change', 'exercise_intervention']]
# drop any rows with nan values
saccades_diff = saccades_diff.dropna(how='any')

# change the column names
saccades_diff = saccades_diff.rename(index=str, columns={'VO2max (ml/kg/min)': 'VO2max'})

# %%
# export to a .csv file
saccades_diff.to_csv('/Users/Charlie/Desktop/saccades_diff_analysis.csv')

# %%
# option to import the .csv if needed
saccades_diff = pd.read_csv('/Users/Charlie/Desktop/saccades_diff_analysis.csv')
del saccades_diff['Unnamed: 0']

# %% [markdown]
# ### Change in eye movement velocity and sex

# %%
saccades_diff.groupby('sex').describe()
# Out:
#     EM_change                                                VO2max        \
#         count   mean   std     min    25%   50%   75%    max  count  mean
# sex
# 0       80.00  13.01 53.87 -155.90 -22.32  5.94 30.16 179.34  80.00 58.89
# 1      112.00 -13.07 51.68 -154.31 -43.37 -8.93 16.13 142.09 112.00 53.97
#
#                                        exercise_intervention                 \
#      std   min   25%   50%   75%   max                 count mean  std  min
# sex
# 0   9.16 46.50 53.00 55.19 63.23 77.00                 80.00 0.75 0.44 0.00
# 1   6.10 40.00 51.53 54.91 56.00 66.80                112.00 0.75 0.43 0.00
#
#
#      25%  50%  75%  max
# sex
# 0   0.75 1.00 1.00 1.00
# 1   0.75 1.00 1.00 1.00

# %% [markdown]
# On average, males have eye movements that are 13 deg/s faster at the 'post' time point, while females exhibit an average reduction in speed by approximately the same magnitude.

# %%
ax = sns.violinplot(x='sex', y='EM_change', data=saccades_diff, hue='exercise_intervention', 
                    split=True, scale='count', inner='quartile')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Post-pre difference in max speed by sex (0=male; 1=female)')
plt.ylabel('Change in eye movement velocity')
plt.show()

# %% [markdown]
# The violin plot above shows the distribution of pre-post changes in eye movement velocity for males (0) and females(1). The legend is referring to the presence (1) or absence(0) of the exercise intervention. Sticks show quartiles and the plots are sized to take into account the number of observations.

# %% [markdown]
# ### Change in eye movement velocity and aerobic capacity

# %%
m, c , r, p, se = stats.linregress(saccades_diff['VO2max'], saccades_diff['EM_change'])
saccades_diff.plot.scatter('VO2max', 'EM_change')
plt.plot(saccades_diff['VO2max'], m*saccades_diff['VO2max'] + c, '-')
plt.title('Change in Eye movement speed aerobic capacity')
plt.show()
print('Pearsons R :: ' + str(r))
print('p-value :: ' + str(p))
print('Standard error :: ' + str(se))
# Out:
# Pearsons R :: 0.145096645691
# p-value :: 0.044640267225
# Standard error :: 0.491545274761
